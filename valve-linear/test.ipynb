# %%
import linePlot as linearTest

# %%
linearTest.calc(-30,30)
linearTest.calc(-15,30)
# Out:
# 在17.267436度附近取得极大差异,光栅尺行程高于电位计行程-0.90%
# 在-17.267436度附近取得极大差异,光栅尺行程高于电位计行程0.90%
# 在14.948424度附近取得极大差异,光栅尺行程高于电位计行程-1.55%
# 在-14.948424度附近取得极大差异,光栅尺行程高于电位计行程0.00%
